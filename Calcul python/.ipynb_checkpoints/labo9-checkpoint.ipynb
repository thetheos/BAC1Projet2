# %% [markdown]
# # Labo 9
# Aquisition des données et caracterisation de notre prototype

# %%
import pandas as pd
import numpy as np
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from pico_plotter import listifier, dir_listifier

# %% [markdown]
# ## Analyse des signaux en sortie du pont H

# %%
data_dic = dir_listifier("picoscope/labo9/sorties point h 50 et 70",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')
df_test.plot(x='time', y = 'chanB')

# %% [markdown]
# ## Analyse des tensions en sortie des ampli-op

# %%
data_dic = dir_listifier("picoscope/labo9/sorties ampliop 50 et 70",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')
df_test.plot(x='time', y = 'chanB')

# %% [markdown]
# ## Analyse des tensions du secondaire à la fréquence de résonance de 19Khz

# %% [markdown]
# ### Tension aux bornes de la bobines

# %%
data_dic = dir_listifier("picoscope/labo9/secondaire_freq_resonance_VF",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')

# %% [markdown]
# ### Sortie du pont de diode

# %%
data_dic = dir_listifier("picoscope/labo9/resistance_secondaire_sans_capa",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')

# %% [markdown]
# ### Sortie du pont de diode filtré par une capa

# %%
data_dic = dir_listifier("picoscope/labo9/resonance_Avec_capa_19Khz",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')

# %% [markdown]
# ## Tension à la sortie du secondaire à d'autres fréquences

# %%
data_dic = dir_listifier("picoscope/labo9/secondaire_capa_pas_resonance_1/",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')

# %%
data_dic = dir_listifier("picoscope/labo9/secondaire_capa_pas_resonance_2/",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')

# %% [markdown]
# ## Tension d'entrée du circuit oscillateur

# %% [markdown]
# ### Entrée dans l'ampli-op

# %%
data_dic = dir_listifier("picoscope/labo9/entrée ampliop 50 et 70",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')

# %% [markdown]
# ## Tension du secondaire après écartement des deux bobines d'une certaine distance

# %% [markdown]
# ### Distance: 1cm
# On observer une tension aux alentour de 3V après le pont redresseur et le filtre de la capa

# %%
data_dic = dir_listifier("picoscope/labo9/resonance_1cm",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')

# %% [markdown]
# ### Distance: 2cm

# %%
data_dic = dir_listifier("picoscope/labo9/resonance2cm",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')

# %% [markdown]
# ### Distance: 3cm

# %%
data_dic = dir_listifier("picoscope/labo9/resonance3cm",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')

# %% [markdown]
# ### Distance 5cm

# %%
data_dic = dir_listifier("picoscope/labo9/resonance5cm",2)
df_test = pd.DataFrame(data_dic)
df_test.plot(x='time', y = 'chanA')

# %% [markdown]
# ## Generate Plotly

# %%
data = []
data.append(go.Scatter(x=df_test.time,y=df_test.chanA,name="Channel A"))
data.append(go.Scatter(x=df_test.time,y=df_test.chanB,name="Channel B"))


plotly.offline.plot({
    "data": data,
    "layout": go.Layout(title="Pico_Plotter", xaxis=dict(title="Time (µs)"), yaxis=dict(title="Volatage (V)")),   
}, filename= "test.html")
# Out:
# 'test.html'
